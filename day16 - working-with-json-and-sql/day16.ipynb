# %%
import pandas as pd

# %% [markdown]
# # Working with JSON

# %%
pd.read_json('../Datasets/train.json')

# %%
pd.read_json('https://api.exchangerate-api.com/v4/latest/INR')

# %% [markdown]
# # Working with SQL

# %%
from sqlalchemy import create_engine

# %%
engine = create_engine("oracle+oracledb://system:system@127.0.0.1:1521/?service_name=XEPDB1")

# %%
df = pd.read_sql_query("SELECT * FROM countrylanguage",engine)

# %%
df
